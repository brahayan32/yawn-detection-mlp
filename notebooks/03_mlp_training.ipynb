# %% [markdown]
# # 03 - Entrenamiento MLP
#
# Entrena el perceptron multicapa con TensorFlow puro, sin Keras.

# %%
from pathlib import Path
import sys
import numpy as np
import tensorflow as tf

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.config import BATCH_SIZE, DATASET_DIR, METRICS_DIR, MODELS_DIR, EPOCHS, RANDOM_STATE
from src.preprocessing import load_all_dataset
from src.model import PureTensorFlowMLP, save_model, train_mlp
from src.evaluation import save_history_plots
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781938308.763663    1531 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781938309.109793    1531 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781938310.598315    1531 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)
data = load_all_dataset(DATASET_DIR)
x_train, y_train, _ = data['train']
x_val, y_val, _ = data['validation']
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((148, 4096), (148,), (31, 4096), (31,))

# %%
model = PureTensorFlowMLP(input_dim=x_train.shape[1], seed=RANDOM_STATE)
print('Entrada:', x_train.shape[1])
print('Arquitectura: 4096 -> 512 ReLU -> 128 ReLU -> 1 Sigmoid')
# Out:
# Entrada: 4096
# Arquitectura: 4096 -> 512 ReLU -> 128 ReLU -> 1 Sigmoid
# I0000 00:00:1781938326.121467    1531 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1763 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
history = train_mlp(
    model,
    x_train,
    y_train,
    x_val=x_val,
    y_val=y_val,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
)

save_history_plots(history, METRICS_DIR)
save_model(model, MODELS_DIR / 'best_model')
# Out:
# Epoca 1/30 - loss: 1.0530 - accuracy: 0.5450 - val_loss: 0.7136 - val_accuracy: 0.4839
# Epoca 2/30 - loss: 0.6889 - accuracy: 0.5513 - val_loss: 0.6746 - val_accuracy: 0.6129
# Epoca 3/30 - loss: 0.5514 - accuracy: 0.7562 - val_loss: 0.6247 - val_accuracy: 0.6774
# Epoca 4/30 - loss: 0.4678 - accuracy: 0.8200 - val_loss: 0.6088 - val_accuracy: 0.6452
# Epoca 5/30 - loss: 0.4144 - accuracy: 0.8313 - val_loss: 0.6403 - val_accuracy: 0.6774
# Epoca 6/30 - loss: 0.3536 - accuracy: 0.8538 - val_loss: 0.6158 - val_accuracy: 0.6452
# Epoca 7/30 - loss: 0.2852 - accuracy: 0.9087 - val_loss: 0.6417 - val_accuracy: 0.6774
# Epoca 8/30 - loss: 0.2716 - accuracy: 0.8925 - val_loss: 0.6611 - val_accuracy: 0.7097
# Epoca 9/30 - loss: 0.2314 - accuracy: 0.9237 - val_loss: 0.6403 - val_accuracy: 0.7419
# Epoca 10/30 - loss: 0.2329 - accuracy: 0.8987 - val_loss: 0.8408 - val_accuracy: 0.6774
# Entrenamiento detenido por Early Stopping.
# INFO:tensorflow:Assets written to: /mnt/c/Users/USUARIO/Documents/PARALELAS/yawn-detection-mlp/models/best_model/assets
# INFO:tensorflow:Assets written to: /mnt/c/Users/USUARIO/Documents/PARALELAS/yawn-detection-mlp/models/best_model/assets
